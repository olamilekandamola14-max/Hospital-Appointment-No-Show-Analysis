# %%
import pandas as pd

# %%
df=pd.read_csv("Hospital_Appointment.csv",  encoding="latin1")
df
# Out:
#            PatientId  AppointmentID Gender             ScheduledDay  \
# 0       4.314930e+14        5640380      M   Friday, April 29, 2016
# 1       6.822850e+13        5642813      M   Friday, April 29, 2016
# 2       5.392419e+10        5641476      M   Friday, April 29, 2016
# 3       1.883370e+14        5640933      M   Friday, April 29, 2016
# 4       1.165340e+12        5640561      M   Friday, April 29, 2016
# ...              ...            ...    ...                      ...
# 110522  5.342900e+12        5778205      F     Monday, June 6, 2016
# 110523  5.342900e+12        5778066      F     Monday, June 6, 2016
# 110524  8.588820e+12        5759465      F  Wednesday, June 1, 2016
# 110525  4.758510e+13        5784948      F    Tuesday, June 7, 2016
# 110526  3.184920e+13        5756880      F  Wednesday, June 1, 2016
#
#                  AppointmentDay  Age   Neighbourhood  Scholarship  \
# 0        Friday, April 29, 2016    0      MONTE BELO            0
# ...

# %%
print(df.head())
print(df.info())
print(df.isnull().sum())
print(df.duplicated().sum())
# Out:
#       PatientId  AppointmentID Gender            ScheduledDay  \
# 0  4.314930e+14        5640380      M  Friday, April 29, 2016
# 1  6.822850e+13        5642813      M  Friday, April 29, 2016
# 2  5.392419e+10        5641476      M  Friday, April 29, 2016
# 3  1.883370e+14        5640933      M  Friday, April 29, 2016
# 4  1.165340e+12        5640561      M  Friday, April 29, 2016
#
#            AppointmentDay  Age   Neighbourhood  Scholarship  Hipertension  \
# 0  Friday, April 29, 2016    0      MONTE BELO            0             0
# 1  Friday, April 29, 2016    0          BONFIM            0             0
# 2  Friday, April 29, 2016    0        ITARARÃ            0             0
# 3  Friday, April 29, 2016    0  NOVA PALESTINA            0             0
# 4  Friday, April 29, 2016    0       CONQUISTA            0             0
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show  WaitingDays Age Group
# ...

# %%
df.rename(columns= {"Hipertension":"Hypertension"},inplace=True)
df
# Out:
#            PatientId  AppointmentID Gender             ScheduledDay  \
# 0       4.314930e+14        5640380      M   Friday, April 29, 2016
# 1       6.822850e+13        5642813      M   Friday, April 29, 2016
# 2       5.392419e+10        5641476      M   Friday, April 29, 2016
# 3       1.883370e+14        5640933      M   Friday, April 29, 2016
# 4       1.165340e+12        5640561      M   Friday, April 29, 2016
# ...              ...            ...    ...                      ...
# 110522  5.342900e+12        5778205      F     Monday, June 6, 2016
# 110523  5.342900e+12        5778066      F     Monday, June 6, 2016
# 110524  8.588820e+12        5759465      F  Wednesday, June 1, 2016
# 110525  4.758510e+13        5784948      F    Tuesday, June 7, 2016
# 110526  3.184920e+13        5756880      F  Wednesday, June 1, 2016
#
#                  AppointmentDay  Age   Neighbourhood  Scholarship  \
# 0        Friday, April 29, 2016    0      MONTE BELO            0
# ...

# %%
df["No-show"].value_counts()
# Out:
# No-show
# No     88208
# Yes    22319
# Name: count, dtype: int64

# %%
df.groupby("Gender")["No-show"].value_counts()
# Out:
# Gender  No-show
# F       No         57246
#         Yes        14594
# M       No         30962
#         Yes         7725
# Name: count, dtype: int64

# %%
df.groupby("Age Group") [["Diabetes","Hypertension"]].agg(["sum","count"])
# Out:
#           Diabetes        Hypertension
#                sum  count          sum  count
# Age Group
# 18 - 30        117  18252          326  18252
# 31 - 45        784  21954         2661  21954
# 46 - 60       2604  23179         7774  23179
# Over 60       4387  19762        11002  19762
# Under 18        51  27380           38  27380

# %%
df["SMS_received"].value_counts()
# Out:
# SMS_received
# 0    75045
# 1    35482
# Name: count, dtype: int64
